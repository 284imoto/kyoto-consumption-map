# %% [markdown]
# ## 京都市中心エリアの消費傾向の地図を作成するプログラム

# %%
# 必要なモジュール
import pandas as pd
import numpy as np
import sys
import os
import geopandas as gpd
import folium
import re
import itertools
import warnings
warnings.simplefilter("ignore")
from collections import defaultdict
import branca

# %%
# 自作モジュール
sys.path.append("../src")
from preprocess import preprocess, get_areadata_from_raw
from classify import classify
from filter import filter_by_date, filter_by_ind_blocks, filter_by_resi_blocks, filter_by_resi2_blocks
from filter import filter_by_ind, filter_by_gender, filter_by_age
from aggregate import process_data_by_ind_block, process_data_by_agesegment_gender, make_ind_age_gender
from aggregate import compute_gender_ratio_by_date_ind, compute_age_gender_ratio_by_date_ind, split_by_resi1
from aggregate import create_time_series_df
from aggregate import aggregate_by_code
from visualize_tool import get_sort_column, sort_by_ninzu_amount
from visualize import create_map_with_graduation, save_map
from heatmap import create_map_with_heatmap

# %%
#dummy_dataへのpath
jcb_path = "../data/dummy_data/dummy_data.csv"

# %%
#dummy_dataの読み込み
jcb_df = pd.read_csv(jcb_path,encoding="shift_jis")
#京都市中心エリアのGeoDataFrameを読み込む
gdf = gpd.read_file("../data/geojson/京都市中心GeoJSONデータ_v3.geojson")

# %%
#データの前処理
jcb_df = preprocess(jcb_df)
jcb_df = classify(jcb_df)
sale_df = jcb_df

# %%
#京都市中心エリアのデータの確認
sale_df.head(3)
# Out:
#         date  post_code address1 address2 address3       ind  ninzu  \
# 0 2023-10-03    6018002      京都府    京都市南区  東九条上殿田町  141_宿泊施設      0
# 1 2023-11-13    6008214      京都府   京都市下京区  東塩小路高倉町    996_小売      0
# 2 2023-04-13    6048182      京都府   京都市中京区    大阪材木町   995_理美容      0
#
#       amount  age  gender resi1    resi2 residence_block ind_block
# 0  156258.43   60       2   茨城県  東茨城郡茨城町  北海道・東北・北関東ブロック  141_宿泊施設
# 1  181815.25   70       2   栃木県      小山市  北海道・東北・北関東ブロック  コンビニスーパー
# 2  165289.54   80       2   京都府   京都市伏見区             京都府   995_理美容

# %%
#京都市中心エリアのGeoDataFrameの確認
gdf.head(3)
# Out:
#        full_address  post_code  clicked  \
# 0  京都府京都市東山区修道石垣町東側    6050913     True
# 1  京都府京都市東山区修道石垣町西側    6050911     True
# 2    京都府京都市東山区修道芳野町    6050878     True
#
#                                             geometry
# 0  POLYGON ((135.77227 34.99422, 135.77223 34.994...
# 1  POLYGON ((135.77176 34.99496, 135.77171 34.994...
# 2  POLYGON ((135.7726 34.99481, 135.7727 34.99472...

# %% [markdown]
# #### 以下はプログラムの実行部分

# %%
#実行する部分
#➀特定の日,➁利用者の居住地,➂オリジナルの業種 をユーザーが入力し、JCBデータを抽出

#ユーザー入力でフィルタリング
# 抽出する期間を指定
start_date = input("期間の初めの日付を入力（例：20230101）：")
end_date = input("期間の終わりの日付を入力（例：20231231）：")
resi_blocks = input("消費者の居住地ブロックをカンマ区切りで入力（例: 東海ブロック,中国ブロック）未入力は全選択:")
resi2_blocks = input("消費者の住所の詳細を入力（例：京都市下京区,京都市上京区）未入力は全選択")
ind = input("オリジナルの業種をカンマ区切りで入力（例：021_ｽｰﾊﾟｰ,124_料理店,141_宿泊施設,181_タクシー）未入力は全選択：")
gender = input("性別を入力（１：男性,２：女性）未入力は全選択：")
age_range = input("年齢範囲を入力（例：20-29）未入力は全選択：")

#順にフィルタリングを適用
filtered_df = filter_by_date(sale_df,start_date=start_date, end_date=end_date)
filtered_df = filter_by_resi_blocks(filtered_df, resi_blocks)
filtered_df = filter_by_resi2_blocks(filtered_df,resi2_blocks)
filtered_df = filter_by_ind(filtered_df,ind)
filtered_df = filter_by_gender(filtered_df,gender)
filtered_df = filter_by_age(filtered_df,age_range)
filtered_df = filtered_df.rename({"code":"post_code"},axis=1)

excel_df = filtered_df.sort_values(by='amount',ascending=False).reset_index()
excel_df = excel_df.drop('index',axis=1)
#amountが多い順に、場所（郵便番号も一緒）、業種、ninzuを抽出した
#CSVファイルはfiltered_dfをCSV出力すれば良い

#郵便番号別で集計を行う
result_df = aggregate_by_code(filtered_df)
#ninzuかamountのユーザー入力による並び替え
#並び替えの基準をユーザー入力で取得
sort_column = get_sort_column()
sorted_df = sort_by_ninzu_amount(result_df,sort_column)
# Out:
# 期間の初めの日付を入力（例：20230101）： 20230101
# 期間の終わりの日付を入力（例：20231231）： 20231231
# 消費者の居住地ブロックをカンマ区切りで入力（例: 東海ブロック,中国ブロック）未入力は全選択: 東京都
# 消費者の住所の詳細を入力（例：京都市下京区,京都市上京区）未入力は全選択
# オリジナルの業種をカンマ区切りで入力（例：021_ｽｰﾊﾟｰ,124_料理店,141_宿泊施設,181_タクシー）未入力は全選択：
# 性別を入力（１：男性,２：女性）未入力は全選択：
# 年齢範囲を入力（例：20-29）未入力は全選択：
# 並び替えの基準を選択してください（a: amount / n: ninzu）： a

# %%
geo_df = gdf.merge(sorted_df,on='post_code',how='left')
value_column = sort_column

# %%
map1 = create_map_with_graduation(geo_df, value_column,"全体")
save_map(map1)
# Out:
# 該当エリアを地図上に表示

# %% [markdown]
# #### 京都市中心エリア全てにおける可視化

# %%
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd957a6ce571d3d195796aa4e3ccdec9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 2px; left: 2px; width: 250px; height: 100px;
#         background-color: white; z-index:9999; font-size:12px;
#         border:2px solid grey; padding:5px;&quot;&gt;
#         &lt;i style=&quot;background:#ff4500; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 1位
#         &lt;i style=&quot;background:#ff7f00; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 2位
#         &lt;i style=&quot;background:#ffd700; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 3位
#         &lt;i style=&quot;background:#32cd32; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 4位
#         &lt;i style=&quot;background:#00fa9a; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 5位&lt;br&gt;
#         &lt;i style=&quot;background:#00ced1; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 6位
#         &lt;i style=&quot;background:#1e90ff; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 7位
#         &lt;i style=&quot;background:#6a5acd; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 8位
#         &lt;i style=&quot;background:#9932cc; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 9位
#         &lt;i style=&quot;background:#8b008b; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 10位&lt;br&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd957a6ce571d3d195796aa4e3ccdec9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd957a6ce571d3d195796aa4e3ccdec9 = L.map(
#                 &quot;map_fd957a6ce571d3d195796aa4e3ccdec9&quot;,
#                 {
#                     center: [35.0116, 135.7681],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c1ab337176f4bdfe06819010aa80f5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c1ab337176f4bdfe06819010aa80f5b.addTo(map_fd957a6ce571d3d195796aa4e3ccdec9);
#
#
#         function geo_json_62e292a1a890f103883f14c8f9597ebf_styler(feature) {
#             switch(feature.id) {
#                 case &quot;928&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ff4500&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;303&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffd700&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;930&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#32cd32&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;63&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#00fa9a&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;62&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#00ced1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;61&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1e90ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;64&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6a5acd&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;60&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9932cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;65&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8b008b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;204&quot;: case &quot;932&quot;: case &quot;203&quot;: case &quot;1136&quot;: case &quot;315&quot;: case &quot;687&quot;: case &quot;311&quot;: case &quot;626&quot;: case &quot;

# %%
core_geo_df = geo_df.dropna(subset=['rank'])

# %%
map2 = create_map_with_graduation(core_geo_df, value_column,"全体")
save_map(map2)
# Out:
# 該当エリアを地図上に表示

# %% [markdown]
# #### 京都市中心エリアにおいて指定した条件のデータがある町を可視化

# %%
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55929a459c0c6e9ba7f7a99f52ba2d2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 2px; left: 2px; width: 250px; height: 100px;
#         background-color: white; z-index:9999; font-size:12px;
#         border:2px solid grey; padding:5px;&quot;&gt;
#         &lt;i style=&quot;background:#ff4500; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 1位
#         &lt;i style=&quot;background:#ff7f00; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 2位
#         &lt;i style=&quot;background:#ffd700; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 3位
#         &lt;i style=&quot;background:#32cd32; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 4位
#         &lt;i style=&quot;background:#00fa9a; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 5位&lt;br&gt;
#         &lt;i style=&quot;background:#00ced1; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 6位
#         &lt;i style=&quot;background:#1e90ff; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 7位
#         &lt;i style=&quot;background:#6a5acd; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 8位
#         &lt;i style=&quot;background:#9932cc; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 9位
#         &lt;i style=&quot;background:#8b008b; width:20px; height:20px; display:inline-block;&quot;&gt;&lt;/i&gt; 10位&lt;br&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55929a459c0c6e9ba7f7a99f52ba2d2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55929a459c0c6e9ba7f7a99f52ba2d2c = L.map(
#                 &quot;map_55929a459c0c6e9ba7f7a99f52ba2d2c&quot;,
#                 {
#                     center: [35.0116, 135.7681],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20948e5651d00043393c49b11c369c5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20948e5651d00043393c49b11c369c5d.addTo(map_55929a459c0c6e9ba7f7a99f52ba2d2c);
#
#
#         function geo_json_003a0ffcc46225878fea4ca3d9a127da_styler(feature) {
#             switch(feature.id) {
#                 case &quot;928&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ff4500&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;303&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffd700&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;930&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#32cd32&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;63&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#00fa9a&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;62&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#00ced1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;61&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1e90ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;64&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6a5acd&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;60&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9932cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;65&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8b008b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;weight&quot;: 1};
#                 case &quot;204&quot;: case &quot;932&quot;: case &quot;203&quot;: case &quot;1136&quot;: case &quot;315&quot;: case &quot;687&quot;: case &quot;311&quot;: case &quot;626&quot;: case &quot;

# %% [markdown]
# #### 消費額の対数変換をヒートマップで可視化

# %%
# 2025/06/13 追加
map3 = create_map_with_heatmap(core_geo_df, value_column)
save_map(map3)
# Out:
# 該当エリアを地図上に表示

# %%
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29854787e7889ef85654370df601e01f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29854787e7889ef85654370df601e01f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29854787e7889ef85654370df601e01f = L.map(
#                 &quot;map_29854787e7889ef85654370df601e01f&quot;,
#                 {
#                     center: [35.0116, 135.7681],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bec6001228b99adfb578a7b8b842d610 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bec6001228b99adfb578a7b8b842d610.addTo(map_29854787e7889ef85654370df601e01f);
#
#
#     var color_map_3873e1c5ac0dd4a0a04e5a9fce0c3b42 = {};
#
#
#     color_map_3873e1c5ac0dd4a0a04e5a9fce0c3b42.color = d3.scale.threshold()
#               .domain([7.353901571697306, 7.37483470508249, 7.395767838467674, 7.416700971852858, 7.437634105238042, 7.4585672386232265, 7.479500372008411, 7.500433505393595, 7.521366638778779, 7.542299772163963, 7.563232905549147, 7.584166038934331, 7.605099172319515, 7.626032305704699, 7.6469654390898825, 7.6678985724750675, 7.688831705860251, 7.709764839245435, 7.730697972630619, 7.751631106015803, 7.772564239400987, 7.793497372786171, 7.814430506171355, 7.835363639556539, 7.8562967729417235, 7.877229906326908, 7.898163039712092, 7.919096173097276, 7.94002930648246, 7.960962439867644, 7.981895573252828, 8.002828706638013, 8.023761840023196, 8.04469497340838, 8.065628106793564, 8.086561240178748, 8.107494373563933, 8.128427506949116, 8.1493606403343, 8.170293773719484, 8.191226907104669, 8.212160040489852, 8.233093173875037, 8.25402630726022, 8.274959440645405, 8.295892574030589, 8.316825707415774, 8.337758840800957, 8.358691974186142, 8.379625107571325, 8.40055824095651, 8.421491374341693, 8.442424507726878, 8.463357641112061, 8.484290774497246, 8.50522390788243, 8.526157041267613, 8.547090174652798, 8.568023308037983, 8.588956441423166, 8.60988957480835, 8.630822708193534, 8.65175584157872, 8.672688974963902, 8.693622108349086, 8.71455524173427, 8.735488375119454, 8.756421508504639, 8.777354641889822, 8.798287775275007, 8.81922090866019, 8.840154042045375, 8.861087175430558, 8.882020308815743, 8.902953442200927, 8.923886575586112, 8.944819708971295, 8.96575284235648, 8.986685975741663, 9.007619109126848, 9.028552242512031, 9.049485375897216, 9.0704185092824, 9.091351642667584, 9.112284776052768, 9.133217909437953, 9.154151042823136, 9.175084176208319, 9.196017309593504, 9.216950442978689, 9.237883576363872, 9.258816709749055, 9.27974984313424, 9.300682976519425, 9.321616109904609, 9.342549243289792, 9.363482376674977, 9.38441551006016, 9.405348643445345, 9.426281776830528, 9.447214910215713, 9.468148043600896, 9.489081176986081, 9.510014310371265, 9.53094744375645, 9.551880577141633, 9.572813710526818, 9.593746843912001, 9.614679977297186, 9.63561311068237, 9.656546244067552, 9.677479377452737, 9.698412510837922, 9.719345644223106, 9.740278777608289, 9.761211910993474, 9.782145044378659, 9.803078177763842, 9.824011311149025, 9.84494444453421, 9.865877577919395, 9.886810711304578, 9.907743844689762, 9.928676978074947, 9.949610111460132, 9.970543244845315, 9.991476378230498, 10.012409511615683, 10.033342645000866, 10.054275778386051, 10.075208911771234, 10.09614204515642, 10.117075178541603, 10.138008311926788, 10.15894144531197, 10.179874578697156, 10.200807712082339, 10.221740845467524, 10.242673978852707, 10.263607112237892, 10.284540245623075, 10.305473379008259, 10.326406512393444, 10.347339645778629, 10.368272779163812, 10.389205912548995, 10.41013904593418, 10.431072179319365, 10.452005312704548, 10.472938446089731, 10.493871579474916, 10.514804712860101, 10.535737846245285, 10.556670979630468, 10.577604113015653, 10.598537246400838, 10.619470379786021, 10.640403513171204, 10.66133664655639, 10.682269779941572, 10.703202913326757, 10.72413604671194, 10.745069180097126, 10.766002313482309, 10.786935446867494, 10.807868580252677, 10.828801713637862, 10.849734847023045, 10.87066798040823, 10.891601113793413, 10.912534247178598, 10.933467380563782, 10.9544005139

# %%
core_geo_df.head(5)
# Out:
#        full_address  post_code  clicked  \
# 0  京都府京都市東山区修道石垣町東側    6050913     True
# 1  京都府京都市東山区修道石垣町西側    6050911     True
# 2    京都府京都市東山区修道芳野町    6050878     True
# 3   京都府京都市東山区修道上棟梁町    6050916     True
# 9     京都府京都市東山区修道袋町    6050911     True
#
#                                             geometry  ninzu      amount   rank
# 0  POLYGON ((135.77227 34.99422, 135.77223 34.994...    0.0   241431.40  792.0
# 1  POLYGON ((135.77176 34.99496, 135.77171 34.994...    0.0  2714207.44  489.0
# 2  POLYGON ((135.7726 34.99481, 135.7727 34.99472...    0.0  2298401.22  516.0
# 3  POLYGON ((135.77192 34.99359, 135.77191 34.993...    0.0   241006.52  793.0
# 9  POLYGON ((135.7713 34.99439, 135.77129 34.9943...    0.0  2714207.44  489.0

# %%
import numpy as np
import matplotlib.pyplot as plt

df = core_geo_df

# 要約統計量
print(df['amount'].describe())
print("歪度 (skewness):", df['amount'].skew())

# ヒストグラム（通常スケール）
plt.figure(figsize=(8,4))
plt.hist(df['amount'], bins=50)
plt.title('amount の分布（通常スケール）')
plt.xlabel('amount')
plt.ylabel('件数')
plt.tight_layout()
plt.show()

# ヒストグラム（対数スケール）
plt.figure(figsize=(8,4))
plt.hist(df['amount'], bins=50, log=False)           # ヒストグラム自体は通常だが
plt.yscale('log')                                    # Y 軸を対数にして表示
plt.title('amount の分布（Y 軸対数スケール）')
plt.xlabel('amount')
plt.ylabel('件数 (log)')
plt.tight_layout()
plt.show()

# 対数変換後の分布（参考）
log_amt = np.log1p(df['amount'])
plt.figure(figsize=(8,4))
plt.hist(log_amt, bins=50)
plt.title('log1p(amount) の分布')
plt.xlabel('log1p(amount)')
plt.ylabel('件数')
plt.tight_layout()
plt.show()
# Out:
# count    9.800000e+02
# mean     2.612578e+07
# std      1.500294e+08
# min      1.374470e+03
# 25%      9.720600e+05
# 50%      3.962096e+06
# 75%      1.626798e+07
# max      2.820367e+09
# Name: amount, dtype: float64
# 歪度 (skewness): 13.92459826659434
